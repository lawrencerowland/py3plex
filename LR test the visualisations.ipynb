# %% [markdown]
# <a href="https://colab.research.google.com/github/lawrencerowland/py3plex/blob/master/LR%20test%20the%20visualisations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/SkBlaz/py3plex
# Out:
# Cloning into 'py3plex'...
# remote: Enumerating objects: 6138, done.
# remote: Counting objects: 100% (2/2), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 6138 (delta 0), reused 0 (delta 0), pack-reused 6136
# Receiving objects: 100% (6138/6138), 422.29 MiB | 21.85 MiB/s, done.
# Resolving deltas: 100% (4349/4349), done.
# Checking out files: 100% (1430/1430), done.

# %%
cd /content/py3plex
# Out:
# /content/py3plex

# %%
## visualization of a simple heterogeneous network
from py3plex.visualization.multilayer import *
from py3plex.visualization.colors import all_color_names,colors_default
from py3plex.core import multinet

 ## you can try the default visualization options --- this is the simplest option/

 ## multilayer
multilayer_network = multinet.multi_layer_network().load_network("./datasets/goslim_mirna.gpickle",directed=False, input_type="gpickle_biomine")
multilayer_network.basic_stats() ## check core imports

 ## a simple hairball plot
multilayer_network.visualize_network(style="hairball")
plt.show()
# Out:
# --------------------
#  Computing core stats of the network
#  --------------------
# MultiGraph with 4427 nodes and 5485 edges
# Number of unique node IDs: 1472
# --------------------
#  Network splitting in progress
#  --------------------
# Beginning parsing..
# 100%|██████████| 100/100 [01:47<00:00,  1.08s/it]
# BarnesHut Approximation  took  11.95  seconds
# Repulsion forces  took  90.96  seconds
# Gravitational forces  took  0.55  seconds
# Attraction forces  took  2.11  seconds
# AdjustSpeedAndApplyForces step  took  1.66  seconds

# %%
# visualization of a simple heterogeneous network
from py3plex.visualization.embedding_visualization import embedding_tools
from py3plex.wrappers import train_node2vec_embedding
import argparse
from collections import Counter
from py3plex.visualization.colors import colors_default
from py3plex.algorithms.community_detection import community_wrapper as cw
from py3plex.visualization.multilayer import draw_multiedges, draw_multilayer_default, hairball_plot, plt
from py3plex.core import multinet
# Out:
# wrappers imported

# %%
# visualization from a simple file
multilayer_network = multinet.multi_layer_network().load_network(
    "./datasets/multinet_k100.txt", directed=False, input_type="multiedgelist")
multilayer_network.basic_stats()
multilayer_network.visualize_network()
#multilayer_network.split_to_layers()
#separate_layers = multilayer_network.separate_layers
plt.show()
# Out:
# --------------------
#  Computing core stats of the network
#  --------------------
# MultiGraph with 146 nodes and 135 edges
# Number of unique node IDs: 81
# --------------------
#  Network splitting in progress
#  --------------------
# 100%|██████████| 100/100 [00:00<00:00, 1277.61it/s]
# BarnesHut Approximation  took  0.02  seconds
# Repulsion forces  took  0.05  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.01  seconds
# 100%|██████████| 100/100 [00:00<00:00, 432.23it/s]
# BarnesHut Approximation  took  0.04  seconds
# Repulsion forces  took  0.16  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.01  seconds
# 100%|██████████| 100/100 [00:00<00:00, 902.61it/s]
# BarnesHut Approximation  took  0.02  seconds
# Repulsion forces  took  0.07  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.01  seconds
# 100%|██████████| 100/100 [00:00<00:00, 3101.63it/s]
# BarnesHut Approximation  took  0.01  seconds
# Repulsion forces  took  0.02  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.00  seconds
# 100%|██████████| 100/100 [00:00<00:00, 1562.02it/s]
# BarnesHut Approximation  took  0.01  seconds
# Repulsion forces  took  0.04  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.00  seconds
# 100%|██████████| 100/100 [00:00<00:00, 6166.28it/s]
# BarnesHut Approximation  took  0.00  seconds
# Repulsion forces  took  0.01  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.00  seconds
# 100%|██████████| 100/100 [00:00<00:00, 2867.66it/s]
# BarnesHut Approximation  took  0.01  seconds
# Repulsion forces  took  0.02  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.00  seconds
# 100%|██████████| 100/100 [00:00<00:00, 5280.24it/s]
# BarnesHut Approximation  took  0.00  seconds
# Repulsion forces  took  0.01  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.01  seconds
# 100%|██████████| 100/100 [00:00<00:00, 16362.91it/s]
# BarnesHut Approximation  took  0.00  seconds
# Repulsion forces  took  0.00  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.00  seconds
# 100%|██████████| 100/100 [00:00<00:00, 25676.79it/s]
# BarnesHut Approximation  took  0.00  seconds
# Repulsion forces  took  0.00  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.00  seconds
# 100%|██████████| 100/100 [00:00<00:00, 2982.40it/s]
# BarnesHut Approximation  took  0.01  seconds
# Repulsion forces  took  0.01  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.00  seconds
# 100%|██████████| 100/100 [00:00<00:00, 3844.56it/s]
# BarnesHut Approximation  took  0.01  seconds
# Repulsion forces  took  0.02  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.00  seconds
# 100%|██████████| 100/100 [00:00<00:00, 30680.30it/s]
# BarnesHut Approximation  took  0.00  seconds
# Repulsion forces  took  0.00  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.00  seconds
# Finished with layout..
# MultiGraph with 16 nodes and 4 edges
# MultiGraph with 37 nodes and 6 edges
# MultiGraph with 21 nodes and 1 edges
# MultiGraph with 8 nodes and 1 edges
# MultiGraph with 17 nodes and 0 edges
# MultiGraph with 6 nodes and 0 edges
# MultiGraph with 9 nodes and 1 edges
# MultiGraph with 5 nodes and 1 edges
# MultiGraph with 3 nodes and 0 edges
# MultiGraph with 2 nodes and 0 edges
# MultiGraph with 11 nodes and 0 edges
# MultiGraph with 9 nodes and 0 edges
# MultiGraph with 2 nodes and 0 edges
# 100%|██████████| 1/1 [00:00<00:00,  6.11it/s]

# %%
# visualization from a simple file
multilayer_network = multinet.multi_layer_network().load_network(
    "./datasets/edgeList.txt", directed=False, input_type="multiedgelist")
multilayer_network.basic_stats()
multilayer_network.visualize_network()
plt.show()
# Out:
# --------------------
#  Computing core stats of the network
#  --------------------
# MultiGraph with 20 nodes and 10 edges
# Number of unique node IDs: 10
# --------------------
#  Network splitting in progress
#  --------------------
# 100%|██████████| 100/100 [00:00<00:00, 6111.92it/s]
# BarnesHut Approximation  took  0.00  seconds
# Repulsion forces  took  0.00  seconds
# Gravitational forces  took  0.01  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.00  seconds
# 100%|██████████| 100/100 [00:00<00:00, 3912.09it/s]
# BarnesHut Approximation  took  0.01  seconds
# Repulsion forces  took  0.01  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.00  seconds
# 100%|██████████| 100/100 [00:00<00:00, 6894.33it/s]
# BarnesHut Approximation  took  0.00  seconds
# Repulsion forces  took  0.01  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.00  seconds
# Finished with layout..
# MultiGraph with 4 nodes and 0 edges
# MultiGraph with 10 nodes and 0 edges
# MultiGraph with 6 nodes and 0 edges
# 100%|██████████| 1/1 [00:00<00:00, 73.58it/s]

# %%
# Warm up - hairball plots
dataset = "./datasets/imdb.gpickle"

# Construct a heterogeneous information network object
multilayer_network = multinet.multi_layer_network().load_network(
    input_file=dataset, directed=True, input_type=dataset.split(".")[-1])

# going full py3plex (default 100 iterations)
multilayer_network.visualize_network(style="diagonal")
plt.show()

# Show some basic statistics
multilayer_network.basic_stats()
hairball_plot(multilayer_network.core_network,
              layout_parameters={"iterations": 5},
              scale_by_size=True,
              legend = True,
              layout_algorithm="force")

plt.show()
# Out:
# Parsing gpickle..
# --------------------
#  Network splitting in progress
#  --------------------
# 100%|██████████| 100/100 [01:37<00:00,  1.02it/s]
# BarnesHut Approximation  took  12.79  seconds
# Repulsion forces  took  82.30  seconds
# Gravitational forces  took  0.52  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  1.48  seconds
# 100%|██████████| 100/100 [00:02<00:00, 43.03it/s]
# BarnesHut Approximation  took  0.31  seconds
# Repulsion forces  took  1.86  seconds
# Gravitational forces  took  0.02  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.06  seconds
# Finished with layout..
# MultiDiGraph with 6087 nodes and 0 edges
# MultiDiGraph with 297 nodes and 0 edges
# 100%|██████████| 4/4 [00:14<00:00,  3.56s/it]
# --------------------
#  Computing core stats of the network
#  --------------------
# MultiDiGraph with 6384 nodes and 14592 edges
# Number of unique node IDs: 6342
# Beginning parsing..
# Using custom init positions!
# 100%|██████████| 5/5 [00:12<00:00,  2.47s/it]
# BarnesHut Approximation  took  0.86  seconds
# Repulsion forces  took  11.12  seconds
# Gravitational forces  took  0.04  seconds
# Attraction forces  took  0.15  seconds
# AdjustSpeedAndApplyForces step  took  0.13  seconds

# %%
# multilayer
multilayer_network = multinet.multi_layer_network().load_network(
    "./datasets/goslim_mirna.gpickle",
    directed=False,
    input_type="gpickle_biomine")
multilayer_network.basic_stats()  # check core imports

# a simple hairball plot
multilayer_network.visualize_network(style="hairball")
plt.show()

multilayer_network = multinet.multi_layer_network().load_network(
    "./datasets/multiL.txt", directed=True, input_type="multiedgelist")
multilayer_network.basic_stats()
multilayer_network.visualize_network(style="diagonal")
plt.show()

multilayer_network = multinet.multi_layer_network().load_network(
    "./datasets/multinet_k100.txt", directed=True, input_type="multiedgelist")
multilayer_network.basic_stats()
multilayer_network.visualize_network()
plt.show()
# Out:
# --------------------
#  Computing core stats of the network
#  --------------------
# MultiGraph with 4427 nodes and 5485 edges
# Number of unique node IDs: 1472
# --------------------
#  Network splitting in progress
#  --------------------
# Beginning parsing..
# 100%|██████████| 100/100 [01:52<00:00,  1.12s/it]
# BarnesHut Approximation  took  12.89  seconds
# Repulsion forces  took  94.33  seconds
# Gravitational forces  took  0.57  seconds
# Attraction forces  took  2.13  seconds
# AdjustSpeedAndApplyForces step  took  1.63  seconds
# --------------------
#  Computing core stats of the network
#  --------------------
# MultiDiGraph with 83 nodes and 224 edges
# Number of unique node IDs: 83
# --------------------
#  Network splitting in progress
#  --------------------
# 100%|██████████| 100/100 [00:00<00:00, 301.13it/s]
# BarnesHut Approximation  took  0.05  seconds
# Repulsion forces  took  0.24  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.02  seconds
# AdjustSpeedAndApplyForces step  took  0.01  seconds
# 100%|██████████| 100/100 [00:00<00:00, 288.58it/s]
# BarnesHut Approximation  took  0.05  seconds
# Repulsion forces  took  0.23  seconds
# Gravitational forces  took  0.02  seconds
# Attraction forces  took  0.03  seconds
# AdjustSpeedAndApplyForces step  took  0.01  seconds
# Finished with layout..
# MultiDiGraph with 40 nodes and 112 edges
# MultiDiGraph with 43 nodes and 112 edges
# 0it [00:00, ?it/s]
# --------------------
#  Computing core stats of the network
#  --------------------
# MultiDiGraph with 146 nodes and 135 edges
# Number of unique node IDs: 90
# --------------------
#  Network splitting in progress
#  --------------------
# 100%|██████████| 100/100 [00:00<00:00, 1296.66it/s]
# BarnesHut Approximation  took  0.02  seconds
# Repulsion forces  took  0.04  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.01  seconds
# 100%|██████████| 100/100 [00:00<00:00, 426.06it/s]
# BarnesHut Approximation  took  0.05  seconds
# Repulsion forces  took  0.16  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.01  seconds
# 100%|██████████| 100/100 [00:00<00:00, 840.96it/s]
# BarnesHut Approximation  took  0.03  seconds
# Repulsion forces  took  0.08  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.01  seconds
# 100%|██████████| 100/100 [00:00<00:00, 4510.05it/s]
# BarnesHut Approximation  took  0.01  seconds
# Repulsion forces  took  0.01  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.00  seconds
# 100%|██████████| 100/100 [00:00<00:00, 1823.79it/s]
# BarnesHut Approximation  took  0.02  seconds
# Repulsion forces  took  0.03  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.00  seconds
# 100%|██████████| 100/100 [00:00<00:00, 5397.45it/s]
# BarnesHut Approximation  took  0.00  seconds
# Repulsion forces  took  0.01  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.00  seconds
# 100%|██████████| 100/100 [00:00<00:00, 3789.92it/s]
# BarnesHut Approximation  took  0.01  seconds
# Repulsion forces  took  0.01  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.00  seconds
# 100%|██████████| 100/100 [00:00<00:00, 4925.49it/s]
# BarnesHut Approximation  took  0.00  seconds
# Repulsion forces  took  0.01  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.00  seconds
# 100%|██████████| 100/100 [00:00<00:00, 15987.44it/s]
# BarnesHut Approximation  took  0.00  seconds
# Repulsion forces  took  0.00  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.00  seconds
# 100%|██████████| 100/100 [00:00<00:00, 25681.51it/s]
# BarnesHut Approximation  took  0.00  seconds
# Repulsion forces  took  0.00  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.00  seconds
# 100%|██████████| 100/100 [00:00<00:00, 3037.68it/s]
# BarnesHut Approximation  took  0.01  seconds
# Repulsion forces  took  0.02  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.00  seconds
# 100%|██████████| 100/100 [00:00<00:00, 3699.63it/s]
# BarnesHut Approximation  took  0.01  seconds
# Repulsion forces  took  0.02  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.00  seconds
# 100%|██████████| 100/100 [00:00<00:00, 15146.81it/s]
# BarnesHut Approximation  took  0.00  seconds
# Repulsion forces  took  0.00  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.00  seconds
# Finished with layout..
# MultiDiGraph with 16 nodes and 4 edges
# MultiDiGraph with 37 nodes and 6 edges
# MultiDiGraph with 21 nodes and 1 edges
# MultiDiGraph with 8 nodes and 1 edges
# MultiDiGraph with 17 nodes and 0 edges
# MultiDiGraph with 6 nodes and 0 edges
# MultiDiGraph with 9 nodes and 1 edges
# MultiDiGraph with 5 nodes and 1 edges
# MultiDiGraph with 3 nodes and 0 edges
# MultiDiGraph with 2 nodes and 0 edges
# MultiDiGraph with 11 nodes and 0 edges
# MultiDiGraph with 9 nodes and 0 edges
# MultiDiGraph with 2 nodes and 0 edges
# 100%|██████████| 1/1 [00:00<00:00,  8.84it/s]

# %%
# multilayer -----------------------------------
multilayer_network = multinet.multi_layer_network().load_network(
    "./datasets/epigenetics.gpickle",
    directed=True,
    input_type="gpickle_biomine")
multilayer_network.basic_stats()  # check core imports
# multilayer_network.visualize_network() ## visualize
# plt.show()

# You can also access individual graphical elements separately!

network_labels, graphs, multilinks = multilayer_network.get_layers(
)  # get layers for visualizat# ion
draw_multilayer_default(graphs,
                        display=False,
                        background_shape="circle",
                        labels=network_labels)

enum = 1
color_mappings = {idx: col for idx, col in enumerate(colors_default)}
for edge_type, edges in multilinks.items():

    #    network_list,multi_edge_tuple,input_type="nodes",linepoints="-.",alphachannel=0.3,linecolor="black",curve_height=1,style="curve2_bezier",linewidth=1,invert=False,linmod="both",resolution=0.1
    print(edge_type)
    if edge_type == "refers_to":
        draw_multiedges(graphs,
                        edges,
                        alphachannel=0.05,
                        linepoints="--",
                        linecolor="lightblue",
                        curve_height=5,
                        linmod="upper",
                        linewidth=0.4)
    elif edge_type == "refers_to":
        draw_multiedges(graphs,
                        edges,
                        alphachannel=0.2,
                        linepoints=":",
                        linecolor="green",
                        curve_height=5,
                        linmod="upper",
                        linewidth=0.3)
    elif edge_type == "belongs_to":
        draw_multiedges(graphs,
                        edges,
                        alphachannel=0.2,
                        linepoints=":",
                        linecolor="red",
                        curve_height=5,
                        linmod="upper",
                        linewidth=0.4)
    elif edge_type == "codes_for":
        draw_multiedges(graphs,
                        edges,
                        alphachannel=0.2,
                        linepoints=":",
                        linecolor="orange",
                        curve_height=5,
                        linmod="upper",
                        linewidth=0.4)
    else:
        draw_multiedges(graphs,
                        edges,
                        alphachannel=0.2,
                        linepoints="-.",
                        linecolor="black",
                        curve_height=5,
                        linmod="both",
                        linewidth=0.4)
    enum += 1
plt.show()
plt.clf()
# Out:
# --------------------
#  Computing core stats of the network
#  --------------------
# MultiDiGraph with 2221 nodes and 2795 edges
# Number of unique node IDs: 803
# --------------------
#  Network splitting in progress
#  --------------------
# 100%|██████████| 100/100 [00:11<00:00,  8.41it/s]
# BarnesHut Approximation  took  2.01  seconds
# Repulsion forces  took  9.24  seconds
# Gravitational forces  took  0.08  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.24  seconds
# 100%|██████████| 100/100 [00:12<00:00,  7.81it/s]
# BarnesHut Approximation  took  1.28  seconds
# Repulsion forces  took  10.80  seconds
# Gravitational forces  took  0.07  seconds
# Attraction forces  took  0.18  seconds
# AdjustSpeedAndApplyForces step  took  0.19  seconds
# 100%|██████████| 100/100 [00:06<00:00, 15.26it/s]
# BarnesHut Approximation  took  0.90  seconds
# Repulsion forces  took  5.29  seconds
# Gravitational forces  took  0.05  seconds
# Attraction forces  took  0.06  seconds
# AdjustSpeedAndApplyForces step  took  0.14  seconds
# 100%|██████████| 100/100 [00:00<00:00, 132.29it/s]
# BarnesHut Approximation  took  0.11  seconds
# Repulsion forces  took  0.59  seconds
# Gravitational forces  took  0.01  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.03  seconds
# 100%|██████████| 100/100 [00:00<00:00, 1672.37it/s]
# BarnesHut Approximation  took  0.01  seconds
# Repulsion forces  took  0.04  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.00  seconds
# 100%|██████████| 100/100 [00:00<00:00, 843.48it/s]
# BarnesHut Approximation  took  0.03  seconds
# Repulsion forces  took  0.08  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.01  seconds
# 100%|██████████| 100/100 [00:00<00:00, 1709.22it/s]
# BarnesHut Approximation  took  0.01  seconds
# Repulsion forces  took  0.04  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.01  seconds
# 100%|██████████| 100/100 [00:00<00:00, 2339.96it/s]
# BarnesHut Approximation  took  0.01  seconds
# Repulsion forces  took  0.03  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.00  seconds
# 100%|██████████| 100/100 [00:00<00:00, 3935.80it/s]
# BarnesHut Approximation  took  0.01  seconds
# Repulsion forces  took  0.01  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.00  seconds
# 100%|██████████| 100/100 [00:00<00:00, 6552.78it/s]
# BarnesHut Approximation  took  0.00  seconds
# Repulsion forces  took  0.00  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.00  seconds
# 100%|██████████| 100/100 [00:00<00:00, 39009.52it/s]
# /content/py3plex/py3plex/core/converters.py:27: RuntimeWarning: invalid value encountered in true_divide
#   np.min(coordinate_matrix[:, 0]))
# /content/py3plex/py3plex/core/converters.py:31: RuntimeWarning: invalid value encountered in true_divide
#   np.min(coordinate_matrix[:, 1]))
# BarnesHut Approximation  took  0.00  seconds
# Repulsion forces  took  0.00  seconds
# Gravitational forces  took  0.00  seconds
# Attraction forces  took  0.00  seconds
# AdjustSpeedAndApplyForces step  took  0.00  seconds
# Finished with layout..
# refers_to
# codes_for
# belongs_to
# is_related_to
# is_located_in
# has
# contains
# participates_in
# is_found_in

# %%
# monotone coloring
draw_multilayer_default(graphs,
                        display=False,
                        background_shape="rectangle",
                        labels=network_labels,
                        networks_color="black",
                        rectanglex=2,
                        rectangley=2,
                        background_color="default")

enum = 1
for edge_type, edges in multilinks.items():
    draw_multiedges(graphs,
                    edges,
                    alphachannel=0.2,
                    linepoints="--",
                    linecolor="black",
                    curve_height=2,
                    linmod="upper",
                    linewidth=0.4)
    enum += 1
plt.show()

# %%
# basic string layout ----------------------------------
multilayer_network = multinet.multi_layer_network().load_network(
    "./datasets/epigenetics.gpickle",
    directed=False,
    label_delimiter="---",
    input_type="gpickle_biomine")
network_colors, graph = multilayer_network.get_layers(style="hairball")
# Out:
# --------------------
#  Network splitting in progress
#  --------------------

# %%
#NOT WORKING CURRENTLY
parser = argparse.ArgumentParser()
parser.add_argument("--input_network", default="/datasets/cora.mat")
parser.add_argument("--input_type", default="sparse_network")
args = parser.parse_args()
# Out:
# usage: ipykernel_launcher.py [-h] [--input_network INPUT_NETWORK]
#                              [--input_type INPUT_TYPE]
# ipykernel_launcher.py: error: unrecognized arguments: -f /root/.local/share/jupyter/runtime/kernel-117f30a5-d40e-4682-b053-a088035e5a31.json
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2

# %%
#NOT TESTED
network = multinet.multi_layer_network().load_network(
    input_file=args.input_network, directed=False, input_type=args.input_type
) 
 # network and group objects must be present within the .mat object

network.basic_stats()  # check core imports

partition = cw.louvain_communities(network.core_network)

# select top n communities by size
top_n = 10
partition_counts = dict(Counter(partition.values()))
top_n_communities = list(partition_counts.keys())[0:top_n]

# assign node colors
color_mappings = dict(zip(top_n_communities, colors_default[0:top_n]))

network_colors = [
    "green"
    if partition[x] in top_n_communities else "black"
    for x in network.get_nodes()
]

# visualize the network's communities!
hairball_plot(network.core_network,
              color_list=network_colors,
              layout_parameters={"iterations": 50},
              scale_by_size=True,
              layout_algorithm="force",
              legend=False)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-8de91052d2cd> in <module>
#       1 network = multinet.multi_layer_network().load_network(
# ----> 2     input_file=args.input_network, directed=False, input_type=args.input_type
#       3 )
#       4  # network and group objects must be present within the .mat object
#       5
#
# NameError: name 'args' is not defined

# %%
#NOT FULLY TESTED
# string layout for larger network -----------------------------------
multilayer_network = multinet.multi_layer_network().load_network(
    "./datasets/soc-Epinions1.edgelist",
    label_delimiter="---",
    input_type="edgelist",
    directed=True)
hairball_plot(multilayer_network.core_network,
              layout_parameters={"iterations": 300})
plt.show()

# embedding-based layout (custom coordinates) -----------------------------------

multilayer_network = multinet.multi_layer_network().load_network(
    "./datasets/goslim_mirna.gpickle",
    directed=False,
    input_type="gpickle_biomine")

multilayer_network.save_network("./datasets/test.edgelist")

# call a specific n2v compiled binary
train_node2vec_embedding.call_node2vec_binary("./datasets/test.edgelist",
                                              "./datasets/test_embedding.emb",
                                              binary="../bin/node2vec",
                                              weighted=False)

# preprocess and check embedding
multilayer_network.load_embedding("./datasets/test_embedding.emb")
output_positions = embedding_tools.get_2d_coordinates_tsne(
    multilayer_network, output_format="pos_dict")

# custom layouts are part of the custom coordinate option
layout_parameters = {}
layout_parameters['pos'] = output_positions  # assign parameters
network_colors, graph = multilayer_network.get_layers(style="hairball")
hairball_plot(graph,
              network_colors,
              layout_algorithm="custom_coordinates",
              layout_parameters=layout_parameters)
plt.show()
# Out:
# Beginning parsing..
# Using custom init positions!
#   1%|          | 3/300 [04:43<7:48:22, 94.62s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-20-9ae49f28a51e> in <module>
#       6     directed=True)
#       7 hairball_plot(multilayer_network.core_network,
# ----> 8               layout_parameters={"iterations": 300})
#       9 plt.show()
#      10
#
# /content/py3plex/py3plex/visualization/multilayer.py in hairball_plot(g, color_list, display, node_size, text_color, node_sizes, layout_parameters, legend, scale_by_size, layout_algorithm, edge_width, alpha_channel, labels, draw, label_font_size)
#     498     # standard force -- directed layout
#     499     if layout_algorithm == "force":
# --> 500         pos = compute_force_directed_layout(g, layout_parameters)
#     501
#     502     # random layout -- used for initialization of more complex algorithms
#
# /content/py3plex/py3plex/visualization/layout_algorithms.py in compute_force_directed_layout(g, layout_parameters, verbose, gravity, strongGravityMode, barnesHutTheta, edgeWeightInfluence, scalingRatio, forceImport)
#      48                 print("Using custom init positions!")
#      49                 pos = forceatlas2.forceatlas2_networkx_layout(
# ---> 50                     g, **layout_parameters)
#      51             else:
#      52                 pos = forceatlas2.forceatlas2_networkx_layout(g)
#
# /content/py3plex/py3plex/visualization/fa2/forceatlas2.py in forceatlas2_networkx_layout(self, G, pos, iterations)
#     260         M = networkx.to_scipy_sparse_matrix(G, dtype='f', format='lil')
#     261         if pos is None:
# --> 262             l = self.forceatlas2(M, pos=None, iterations=iterations)
#     263         else:
#     264             poslist = numpy.asarray([pos[i] for i in G.nodes()])
#
# /content/py3plex/py3plex/visualization/fa2/forceatlas2.py in forceatlas2(self, G, pos, iterations)
#     208             if self.barnesHutOptimize:
#     209                 rootRegion.applyForceOnNodes(nodes, self.barnesHutTheta,
# --> 210                                              self.scalingRatio)
#     211             else:
#     212                 fa2util.apply_repulsion(nodes, self.scalingRatio)
#
# /content/py3plex/py3plex/visualization/fa2/fa2util.py in applyForceOnNodes(self, nodes, theta, coefficient)
#     260     def applyForceOnNodes(self, nodes, theta, coefficient=0):
#     261         for n in nodes:
# --> 262             self.applyForce(n, theta, coefficient)
#     263
#     264
#
# /content/py3plex/py3plex/visualization/fa2/fa2util.py in applyForce(self, n, theta, coefficient)
#     256             else:
#     257                 for subregion in self.subregions:
# --> 258                     subregion.applyForce(n, theta, coefficient)
#     259
#     260     def applyForceOnNodes(self, nodes, theta, coefficient=0):
#
# /content/py3plex/py3plex/visualization/fa2/fa2util.py in applyForce(self, n, theta, coefficient)
#     256             else:
#     257                 for subregion in self.subregions:
# --> 258                     subregion.applyForce(n, theta, coefficient)
#     259
#     260     def applyForceOnNodes(self, nodes, theta, coefficient=0):
#
# /content/py3plex/py3plex/visualization/fa2/fa2util.py in applyForce(self, n, theta, coefficient)
#     256             else:
#     257                 for subregion in self.subregions:
# --> 258                     subregion.applyForce(n, theta, coefficient)
#     259
#     260     def applyForceOnNodes(self, nodes, theta, coefficient=0):
#
# /content/py3plex/py3plex/visualization/fa2/fa2util.py in applyForce(self, n, theta, coefficient)
#     256             else:
#     257                 for subregion in self.subregions:
# --> 258                     subregion.applyForce(n, theta, coefficient)
#     259
#     260     def applyForceOnNodes(self, nodes, theta, coefficient=0):
#
# /content/py3plex/py3plex/visualization/fa2/fa2util.py in applyForce(self, n, theta, coefficient)
#     253                             (n.y - self.massCenterY)**2)
#     254             if distance * theta > self.size:
# --> 255                 linRepulsion_region(n, self, coefficient)
#     256             else:
#     257                 for subregion in self.subregions:
#
# /content/py3plex/py3plex/visualization/fa2/fa2util.py in linRepulsion_region(n, r, coefficient)
#      61     if distance2 > 0:
#      62         factor = coefficient * n.mass * r.mass / distance2
# ---> 63         n.dx += xDist * factor
#      64         n.dy += yDist * factor
#      65
#
# KeyboardInterrupt:
